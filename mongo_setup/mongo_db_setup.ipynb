# %%
import requests
from pprint import pprint
from config import api_key
import json
from pymongo import MongoClient
import pandas as pd

# %%
url_cng = f"https://developer.nrel.gov/api/alt-fuel-stations/v1.json?api_key={api_key}&fuel_type=CNG"

response = requests.get(url_cng)

cng = response.json()
cng_json = json.dumps(cng['fuel_stations'], indent=4, sort_keys=False)

with open("ev_cng.json", "w") as outfile:
    outfile.write(cng_json)
# print(cng_json)

# %%
urlelec = f"https://developer.nrel.gov/api/alt-fuel-stations/v1.json?api_key={api_key}&fuel_type=ELEC"

response = requests.get(urlelec)

elec = response.json()
elec_json = json.dumps(elec['fuel_stations'], indent=4, sort_keys=False)

with open("ev_elec.json", "w") as outfile:
    outfile.write(elec_json)
# print(elec_json)

# %%
urlbd = f"https://developer.nrel.gov/api/alt-fuel-stations/v1.json?api_key={api_key}&fuel_type=BD"
response = requests.get(urlbd)

bd = response.json()
bd_json = json.dumps(bd['fuel_stations'], indent=4, sort_keys=False)

with open("ev_bd.json", "w") as outfile:
    outfile.write(bd_json)
# print(bd_json)

# %%
urle85 = f"https://developer.nrel.gov/api/alt-fuel-stations/v1.json?api_key={api_key}&fuel_type=E85"
response = requests.get(urle85)

e85 = response.json()
e85_json = json.dumps(e85['fuel_stations'], indent=4, sort_keys=False)

with open("ev_e85.json", "w") as outfile:
    outfile.write(e85_json)
# print(e85_json)

# %%
urlhy = f"https://developer.nrel.gov/api/alt-fuel-stations/v1.json?api_key={api_key}&fuel_type=HY"
response = requests.get(urlhy)

hy = response.json()
hy_json = json.dumps(hy['fuel_stations'], indent=4, sort_keys=False)

with open("ev_hy.json", "w") as outfile:
    outfile.write(hy_json)
# print(hy_json)

# %%
urllng = f"https://developer.nrel.gov/api/alt-fuel-stations/v1.json?api_key={api_key}&fuel_type=LNG"
response = requests.get(urllng)

lng = response.json()
lng_json = json.dumps(lng['fuel_stations'], indent=4, sort_keys=False)

with open("ev_lng.json", "w") as outfile:
    outfile.write(lng_json)
# print(lng_json)

# %%
urllpg = f"https://developer.nrel.gov/api/alt-fuel-stations/v1.json?api_key={api_key}&fuel_type=LPG"
response = requests.get(urllpg)

lpg = response.json()
lpg_json = json.dumps(lpg['fuel_stations'], indent=4, sort_keys=False)

with open("ev_lpg.json", "w") as outfile:
    outfile.write(lpg_json)
# print(lpg_json)

# %%
urlrd = f"https://developer.nrel.gov/api/alt-fuel-stations/v1.json?api_key={api_key}&fuel_type=RD"
response = requests.get(urlrd)

rd = response.json()
rd_json = json.dumps(rd['fuel_stations'], indent=4, sort_keys=False)

with open("ev_rd.json", "w") as outfile:
    outfile.write(rd_json)
# print(rd_json)

# %%
mongo = MongoClient(port=27017)

ev_db = mongo['ev_db']
fuel_collection = ev_db.fuel_stations
db = mongo['db']

# %%
fuel_stations = pd.read_json('Final collection/ev_db.fuel_stations.json')
fuel_stations
# Out:
#                                         _id access_code  \
# 0      {'$oid': '64d2fd14fdf35c33390e7989'}     private
# 1      {'$oid': '64d2fd14fdf35c33390e798a'}     private
# 2      {'$oid': '64d2fd14fdf35c33390e798b'}     private
# 3      {'$oid': '64d2fd14fdf35c33390e798c'}     private
# 4      {'$oid': '64d2fd14fdf35c33390e798d'}      public
# ...                                     ...         ...
# 73896  {'$oid': '64d2fe354b9181d5d22223e5'}      public
# 73897  {'$oid': '64d2fe354b9181d5d22223e6'}      public
# 73898  {'$oid': '64d2fe354b9181d5d22223e7'}      public
# 73899  {'$oid': '64d2fe354b9181d5d22223e8'}      public
# 73900  {'$oid': '64d2fe354b9181d5d22223e9'}      public
#
#                                         access_days_time  access_detail_code  \
# 0                                                   None          GOVERNMENT
# 1                                                   None          GOVERNMENT
# 2                                                   None          GOVERNMENT
# 3                                                   None          GOVERNMENT
# 4                                         24 hours daily                None
# ...                                                  ...                 ...
# 73896  24 hours daily; contact station to arrange car...                None
# 73897                                     24 hours daily                None
# 73898  24 hours daily; contact station to arrange for...  CREDIT_CARD_ALWAYS
# 73899                                     24 Hours Daily                None
# 73900                                     24 hours daily                None
#
#                                           cards_accepted date_last_confirmed  \
# 0                                                   None          2022-04-06
# 1                                                   None          2022-04-06
# 2                                                   None          2022-07-12
# 3                                                   None          2022-04-06
# 4                                    A Cash Checks D M V          2023-07-11
# ...                                                  ...                 ...
# 73896                     A Cash D FleetOne M Trillium V          2023-02-13
# 73897                     A Cash D FleetOne M Trillium V          2023-06-12
# 73898                               A CREDIT D Debit M V          2023-05-03
# 73899  A ANDROID_PAY APPLE_PAY Cash CREDIT D Debit M ...                None
# 73900                                  Cash CREDIT Debit                None
#
#       expected_date fuel_type_code            groups_with_access_code      id  \
# 0              None             BD          Private - Government only   21781
# 1              None             BD          Private - Government only   21784
# 2              None             BD          Private - Government only   21767
# 3              None             BD          Private - Government only   21785
# 4              None             BD                             Public   21113
# ...             ...            ...                                ...     ...
# 73896          None             RD                             Public  240928
# 73897          None             RD                             Public  241000
# 73898          None             RD  Public - Credit card at all times  259918
# 73899          None             RD                             Public  302316
# 73900          None             RD                             Public  302320
#
#        ... rd_blended_with_biodiesel rd_max_biodiesel_level nps_unit_name  \
# 0      ...                      None                    NaN          None
# 1      ...                      None                    NaN          None
# 2      ...                      None                    NaN          None
# 3      ...                      None                    NaN          None
# 4      ...                      None                    NaN          None
# ...    ...                       ...                    ...           ...
# 73896  ...                         N                    NaN          None
# 73897  ...                         Y                   20.0          None
# 73898  ...                      None                    NaN          None
# 73899  ...                         N                    NaN          None
# 73900  ...                      None                    NaN          None
#
#        access_days_time_fr intersection_directions_fr bd_blends_fr  \
# 0                      NaN                        NaN          NaN
# 1                      NaN                        NaN          NaN
# 2                      NaN                        NaN          NaN
# 3                      NaN                        NaN          NaN
# 4                      NaN                        NaN          NaN
# ...                    ...                        ...          ...
# 73896                  NaN                        NaN          NaN
# 73897                  NaN                        NaN          NaN
# 73898                  NaN                        NaN          NaN
# 73899                  NaN                        NaN          NaN
# 73900                  NaN                        NaN          NaN
#
#                    groups_with_access_code_fr ev_pricing_fr  \
# 0             Privé - Réservé au gouvernement           NaN
# 1             Privé - Réservé au gouvernement           NaN
# 2             Privé - Réservé au gouvernement           NaN
# 3             Privé - Réservé au gouvernement           NaN
# 4                                      Public           NaN
# ...                                       ...           ...
# 73896                                  Public           NaN
# 73897                                  Public           NaN
# 73898  Public - Carte de crédit en tout temps           NaN
# 73899                                  Public           NaN
# 73900                                  Public           NaN
#
#                                           federal_agency ev_network_ids
# 0                                                    NaN            NaN
# 1                                                    NaN            NaN
# 2      {'id': 16, 'code': 'DOI', 'name': 'Department ...            NaN
# 3                                                    NaN            NaN
# 4                                                    NaN            NaN
# ...                                                  ...            ...
# 73896                                                NaN            NaN
# 73897                                                NaN            NaN
# 73898                                                NaN            NaN
# 73899                                                NaN            NaN
# 73900                                                NaN            NaN
#
# [73901 rows x 73 columns]

# %%
# fuel_stations = fuel_stations.drop(['_id'], axis=1) 
# fuel_stations = fuel_stations.reset_index() 
f = fuel_stations.head()
f = f.drop(['_id'], axis=1) 
# f = f.drop(['index'])
f['id'] = f['id'].values.astype(str)
f = f.set_index(['id'])

# %%
f
# Out:
#       access_code access_days_time access_detail_code       cards_accepted  \
# id
# 21781     private             None         GOVERNMENT                 None
# 21784     private             None         GOVERNMENT                 None
# 21767     private             None         GOVERNMENT                 None
# 21785     private             None         GOVERNMENT                 None
# 21113      public   24 hours daily               None  A Cash Checks D M V
#
#       date_last_confirmed expected_date fuel_type_code  \
# id
# 21781          2022-04-06          None             BD
# 21784          2022-04-06          None             BD
# 21767          2022-07-12          None             BD
# 21785          2022-04-06          None             BD
# 21113          2023-07-11          None             BD
#
#          groups_with_access_code   open_date owner_type_code  ...  \
# id                                                            ...
# 21781  Private - Government only  2003-01-15              SG  ...
# 21784  Private - Government only  2003-01-15              SG  ...
# 21767  Private - Government only  2002-12-15              FG  ...
# 21785  Private - Government only  2003-01-15              SG  ...
# 21113                     Public  2001-05-15               P  ...
#
#       rd_blended_with_biodiesel  rd_max_biodiesel_level nps_unit_name  \
# id
# 21781                      None                     NaN          None
# 21784                      None                     NaN          None
# 21767                      None                     NaN          None
# 21785                      None                     NaN          None
# 21113                      None                     NaN          None
#
#       access_days_time_fr intersection_directions_fr bd_blends_fr  \
# id
# 21781                 NaN                        NaN          NaN
# 21784                 NaN                        NaN          NaN
# 21767                 NaN                        NaN          NaN
# 21785                 NaN                        NaN          NaN
# 21113                 NaN                        NaN          NaN
#
#             groups_with_access_code_fr ev_pricing_fr  \
# id
# 21781  Privé - Réservé au gouvernement           NaN
# 21784  Privé - Réservé au gouvernement           NaN
# 21767  Privé - Réservé au gouvernement           NaN
# 21785  Privé - Réservé au gouvernement           NaN
# 21113                           Public           NaN
#
#                                           federal_agency  ev_network_ids
# id
# 21781                                                NaN             NaN
# 21784                                                NaN             NaN
# 21767  {'id': 16, 'code': 'DOI', 'name': 'Department ...             NaN
# 21785                                                NaN             NaN
# 21113                                                NaN             NaN
#
# [5 rows x 71 columns]

# %%
# fuel_stations = fuel_stations.to_dict()
# fuel_stations

f = f.to_dict()
f
# Out:
# {'access_code': {'21781': 'private',
#   '21784': 'private',
#   '21767': 'private',
#   '21785': 'private',
#   '21113': 'public'},
#  'access_days_time': {'21781': None,
#   '21784': None,
#   '21767': None,
#   '21785': None,
#   '21113': '24 hours daily'},
#  'access_detail_code': {'21781': 'GOVERNMENT',
#   '21784': 'GOVERNMENT',
#   '21767': 'GOVERNMENT',
#   '21785': 'GOVERNMENT',
#   '21113': None},
#  'cards_accepted': {'21781': None,
#   '21784': None,
#   '21767': None,
#   '21785': None,
#   '21113': 'A Cash Checks D M V'},
#  'date_last_confirmed': {'21781': '2022-04-06',
#   '21784': '2022-04-06',
#   '21767': '2022-07-12',
#   '21785': '2022-04-06',
#   '21113': '2023-07-11'},
#  'expected_date': {'21781': None,
#   '21784': None,
#   '21767': None,
#   '21785': None,
#   '21113': None},
#  'fuel_type_code': {'21781': 'BD',
#   '21784': 'BD',
#   '21767': 'BD',
#   '21785': 'BD',
#   '21113': 'BD'},
#  'groups_with_access_code': {'21781': 'Private - Government only',
#   '21784': 'Private - Government only',
#   '21767': 'Private - Government only',
#   '21785': 'Private - Government only',
#   '21113': 'Public'},
#  'open_date': {'21781': '2003-01-15',
#   '21784': '2003-01-15',
#   '21767': '2002-12-15',
#   '21785': '2003-01-15',
#   '21113': '2001-05-15'},
#  'owner_type_code': {'21781': 'SG',
#   '21784': 'SG',
#   '21767': 'FG',
#   '21785': 'SG',
#   '21113': 'P'},
#  'status_code': {'21781': 'E',
#   '21784': 'E',
#   '21767': 'E',
#   '21785': 'E',
#   '21113': 'E'},
#  'restricted_access': {'21781': nan,
#   '21784': nan,
#   '21767': nan,
#   '21785': nan,
#   '21113': 0.0},
#  'maximum_vehicle_class': {'21781': None,
#   '21784': None,
#   '21767': None,
#   '21785': None,
#   '21113': 'HD'},
#  'station_name': {'21781': 'Durham County - North Carolina DOT',
#   '21784': 'Vance County - North Carolina DOT',
#   '21767': 'Pictured Rocks National Lakeshore - South',
#   '21785': 'Warren County - North Carolina DOT',
#   '21113': "Dr. Dan's Alternative Fuels Werks"},
#  'station_phone': {'21781': None,
#   '21784': None,
#   '21767': None,
#   '21785': None,
#   '21113': '206-783-5728'},
#  'updated_at': {'21781': Timestamp('2023-02-14 15:54:11+0000', tz='UTC'),
#   '21784': Timestamp('2023-02-14 15:54:11+0000', tz='UTC'),
#   '21767': Timestamp('2023-07-14 21:08:14+0000', tz='UTC'),
#   '21785': Timestamp('2023-02-14 15:54:11+0000', tz='UTC'),
#   '21113': Timestamp('2023-07-11 18:28:56+0000', tz='UTC')},
#  'facility_type': {'21781': 'STATE_GOV',
#   '21784': 'STATE_GOV',
#   '21767': 'NATL_PARK',
#   '21785': 'STATE_GOV',
#   '21113': 'CONVENIENCE_STORE'},
#  'geocode_status': {'21781': '200-8',
#   '21784': '200-8',
#   '21767': 'GPS',
#   '21785': 'GPS',
#   '21113': '200-9'},
#  'latitude': {'21781': 36.06297,
#   '21784': 36.269917,
#   '21767': 46.42113,
#   '21785': 36.395211,
#   '21113': 47.66525},
#  'longitude': {'21781': -78.930276,
#   '21784': -78.369648,
#   '21767': -86.610718,
#   '21785': -78.173533,
#   '21113': -122.369311},
#  'city': {'21781': 'Durham',
#   '21784': 'Henderson',
#   '21767': 'Munising',
#   '21785': 'Warrenton',
#   '21113': 'Seattle'},
#  'intersection_directions': {'21781': 'Prison Camp Road off State Route 1003, 2 miles N of I-85',
#   '21784': 'On State Route 1519 just off NC 39, 4 miles south of Henderson',
#   '21767': None,
#   '21785': '0.5 mile west of Warrenton',
#   '21113': 'For more information, visit https://drdansbiodiesel.com.'},
#  'plus4': {'21781': nan,
#   '21784': nan,
#   '21767': nan,
#   '21785': nan,
#   '21113': nan},
#  'state': {'21781': 'NC',
#   '21784': 'NC',
#   '21767': 'MI',
#   '21785': 'NC',
#   '21113': 'WA'},
#  'street_address': {'21781': '3910 Guess Rd',
#   '21784': '465 Gillburg Rd',
#   '21767': 'E 9758 County Highway 958',
#   '21785': 'State Route 1001',
#   '21113': '912 NW 50th St'},
#  'zip': {'21781': '27705',
#   '21784': '27537',
#   '21767': '49862',
#   '21785': '27589',
#   '21113': '98107'},
#  'country': {'21781': 'US',
#   '21784': 'US',
#   '21767': 'US',
#   '21785': 'US',
#   '21113': 'US'},
#  'bd_blends': {'21781': 'B20',
#   '21784': 'B20',
#   '21767': 'B20',
#   '21785': 'B20',
#   '21113': 'B99'},
#  'cng_dispenser_num': {'21781': nan,
#   '21784': nan,
#   '21767': nan,
#   '21785': nan,
#   '21113': nan},
#  'cng_fill_type_code': {'21781': None,
#   '21784': None,
#   '21767': None,
#   '21785': None,
#   '21113': None},
#  'cng_psi': {'21781': None,
#   '21784': None,
#   '21767': None,
#   '21785': None,
#   '21113': None},
#  'cng_renewable_source': {'21781': None,
#   '21784': None,
#   '21767': None,
#   '21785': None,
#   '21113': None},
#  'cng_total_compression': {'21781': nan,
#   '21784': nan,
#   '21767': nan,
#   '21785': nan,
#   '21113': nan},
#  'cng_total_storage': {'21781': nan,
#   '21784': nan,
#   '21767': nan,
#   '21785': nan,
#   '21113': nan},
#  'cng_vehicle_class': {'21781': None,
#   '21784': None,
#   '21767': None,
#   '21785': None,
#   '21113': None},
#  'cng_has_rng': {'21781': nan,
#   '21784': nan,
#   '21767': nan,
#   '21785': nan,
#   '21113': nan},
#  'e85_blender_pump': {'21781': nan,
#   '21784': nan,
#   '21767': nan,
#   '21785': nan,
#   '21113': nan},
#  'e85_other_ethanol_blends': {'21781': None,
#   '21784': None,
#   '21767': None,
#   '21785': None,
#   '21113': None},
#  'ev_connector_types': {'21781': None,
#   '21784': None,
#   '21767': None,
#   '21785': None,
#   '21113': None},
#  'ev_dc_fast_num': {'21781': nan,
#   '21784': nan,
#   '21767': nan,
#   '21785': nan,
#   '21113': nan},
#  'ev_level1_evse_num': {'21781': nan,
#   '21784': nan,
#   '21767': nan,
#   '21785': nan,
#   '21113': nan},
#  'ev_level2_evse_num': {'21781': nan,
#   '21784': nan,
#   '21767': nan,
#   '21785': nan,
#   '21113': nan},
#  'ev_network': {'21781': None,
#   '21784': None,
#   '21767': None,
#   '21785': None,
#   '21113': None},
#  'ev_network_web': {'21781': None,
#   '21784': None,
#   '21767': None,
#   '21785': None,
#   '21113': None},
#  'ev_other_evse': {'21781': None,
#   '21784': None,
#   '21767': None,
#   '21785': None,
#   '21113': None},
#  'ev_pricing': {'21781': None,
#   '21784': None,
#   '21767': None,
#   '21785': None,
#   '21113': None},
#  'ev_renewable_source': {'21781': None,
#   '21784': None,
#   '21767': None,
#   '21785': None,
#   '21113': None},
#  'hy_is_retail': {'21781': nan,
#   '21784': nan,
#   '21767': nan,
#   '21785': nan,
#   '21113': nan},
#  'hy_pressures': {'21781': None,
#   '21784': None,
#   '21767': None,
#   '21785': None,
#   '21113': None},
#  'hy_standards': {'21781': None,
#   '21784': None,
#   '21767': None,
#   '21785': None,
#   '21113': None},
#  'hy_status_link': {'21781': None,
#   '21784': None,
#   '21767': None,
#   '21785': None,
#   '21113': None},
#  'lng_renewable_source': {'21781': None,
#   '21784': None,
#   '21767': None,
#   '21785': None,
#   '21113': None},
#  'lng_vehicle_class': {'21781': None,
#   '21784': None,
#   '21767': None,
#   '21785': None,
#   '21113': None},
#  'lng_has_rng': {'21781': nan,
#   '21784': nan,
#   '21767': nan,
#   '21785': nan,
#   '21113': nan},
#  'lpg_primary': {'21781': nan,
#   '21784': nan,
#   '21767': nan,
#   '21785': nan,
#   '21113': nan},
#  'lpg_nozzle_types': {'21781': None,
#   '21784': None,
#   '21767': None,
#   '21785': None,
#   '21113': None},
#  'ng_fill_type_code': {'21781': None,
#   '21784': None,
#   '21767': None,
#   '21785': None,
#   '21113': None},
#  'ng_psi': {'21781': None,
#   '21784': None,
#   '21767': None,
#   '21785': None,
#   '21113': None},
#  'ng_vehicle_class': {'21781': None,
#   '21784': None,
#   '21767': None,
#   '21785': None,
#   '21113': None},
#  'rd_blends': {'21781': None,
#   '21784': None,
#   '21767': None,
#   '21785': None,
#   '21113': None},
#  'rd_blends_fr': {'21781': nan,
#   '21784': nan,
#   '21767': nan,
#   '21785': nan,
#   '21113': nan},
#  'rd_blended_with_biodiesel': {'21781': None,
#   '21784': None,
#   '21767': None,
#   '21785': None,
#   '21113': None},
#  'rd_max_biodiesel_level': {'21781': nan,
#   '21784': nan,
#   '21767': nan,
#   '21785': nan,
#   '21113': nan},
#  'nps_unit_name': {'21781': None,
#   '21784': None,
#   '21767': None,
#   '21785': None,
#   '21113': None},
#  'access_days_time_fr': {'21781': nan,
#   '21784': nan,
#   '21767': nan,
#   '21785': nan,
#   '21113': nan},
#  'intersection_directions_fr': {'21781': nan,
#   '21784': nan,
#   '21767': nan,
#   '21785': nan,
#   '21113': nan},
#  'bd_blends_fr': {'21781': nan,
#   '21784': nan,
#   '21767': nan,
#   '21785': nan,
#   '21113': nan},
#  'groups_with_access_code_fr': {'21781': 'Privé - Réservé au gouvernement',
#   '21784': 'Privé - Réservé au gouvernement',
#   '21767': 'Privé - Réservé au gouvernement',
#   '21785': 'Privé - Réservé au gouvernement',
#   '21113': 'Public'},
#  'ev_pricing_fr': {'21781': nan,
#   '21784': nan,
#   '21767': nan,
#   '21785': nan,
#   '21113': nan},
#  'federal_agency': {'21781': nan,
#   '21784': nan,
#   '21767': {'id': 16, 'code': 'DOI', 'name': 'Department of the Interior'},
#   '21785': nan,
#   '21113': nan},
#  'ev_network_ids': {'21781': nan,
#   '21784': nan,
#   '21767': nan,
#   '21785': nan,
#   '21113': nan}}

# %%
# fuel_collection.find_one()
db.fuel_stations.insert_one(f)

# %% [markdown]
# Enter the following  into git terminal to create and add to fuel station collection:
#
#     mongoimport --type json -d ev_db -c fuel_stations --drop --jsonArray ev_bd.json
#
# Modify the text above to add other fuel type JSON files to the existing fuel station collection:
#
#     mongoimport --type json -d ev_db -c fuel_stations --jsonArray ev_cng.json
